# %%
# Data Structures are type of built-in data types which allows to hold certain data.
# Every programming language Data Structures are different but similar in most cases.
# In python, List, Dictionaries, Sets, etc. are the Data Structures.

# %%
# The important element to understand DSA is with 'O' notations. This notations calculates
# space and time compexity of the programs. 
# There are certain rules to calculate Big O notation.
# Step 1: Removing contants
# Step 2: Considering only fastest growing value
# Step 3: Drop constant from fasst growing calculation values

# Big O notation is rough calculation of time and space complexity. 
# That's the reason, constants and small calculated values are dropped.
