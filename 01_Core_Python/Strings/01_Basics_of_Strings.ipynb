# %%
a = "Hello Python"

print(a)
# Out:
# Hello Python

# %%
# length of a string

print(len(a))
# Out:
# 12

# %%
a = 'Hello Python' 

# String in single quotes same as in double qutes

# %%
print(type(a))

# check if a variable is of string type
# Out:
# <class 'str'>

# %%
a = """
this is a multiline string
we can write as a paragraph
this can be in single or 
double quotes
"""

print(a)
# Out:
# this is a multiline string
# we can write as a paragraph
# this can be in single or
# double quotes

# %%
# Check for substring in string

a_str = "this is a complete sentence"

if 'this' in a_str:
    print("Exists")
# Out:
# Exists

# %%
# other way to check a word or substring in string

print("complete" in a_str)
# Out:
# True

# %%
# Strings as an array where each character can be access through indexing

b_str = "string can be an array"

print(b_str[0])
# Out:
# s

# %%
for i in range(0, len(b_str)):
    print(b_str[i])
# Out:
# s
# t
# r
# i
# n
# g
#
# c
# a
# n
#
# b
# e
#
# a
# n
#
# a
# r
# r
# a
# y
